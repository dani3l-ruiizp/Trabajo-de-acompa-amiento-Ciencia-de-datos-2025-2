# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
df = pd.read_csv('/content/REGISTROS_SANITARIOS_DE_MEDICAMENTOS_HOMEOPÁTICOS_20251219.csv')
df.head()
# Out:
#    EXPEDIENTE    REGISTRO_SANITARIO  \
# 0      207398            NO REPORTA
# 1      207276            NO REPORTA
# 2      206425            NO REPORTA
# 3      204949  INVIMA 2001N-0000008
# 4      216969  INVIMA 2002N-0000105
#
#                                             PRODUCTO TIPOPRODUCTO  \
# 0                              EXTRACTO DE VALERIANA   NO REPORTA
# 1                                          ARLELLIUM   NO REPORTA
# 2                                             DIULED   NO REPORTA
# 3               BRONQUIOLIV MALVA SYLVESTRIS - MALVA   NO REPORTA
# 4  TARAXACUM OFFICINALIS DIENTE DE LEON SOLUCION ...   NO REPORTA
#
#   TIPO_IDENTIFICACION_TITULAR IDENTIFICACION_TITULAR  \
# 0                          NI          8.603.519.554
# 1                          NI          8.603.519.654
# 2                          NI          8.603.519.654
# 3                          NI          8.603.519.654
# 4                          NI          8.603.519.654
#
#                         TITULAR        DIRECCIÓN_TITULAR CIUDAD_TITULAR  \
# 0  LABORATORIOS PRONABELL S A S  CARRERA 12 NO 24 B - 45          FUNZA
# 1   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
# 2   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
# 3   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
# 4   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
#
#           ROL          MODALIDAD ESTADO_REGISTRO  \
# 0  FABRICANTE  FABRICAR Y VENDER          NEGADO
# 1  FABRICANTE  FABRICAR Y VENDER          NEGADO
# 2  FABRICANTE  FABRICAR Y VENDER          NEGADO
# 3  FABRICANTE  FABRICAR Y VENDER         VENCIDO
# 4  FABRICANTE  FABRICAR Y VENDER         VENCIDO
#
#                                     PRINCIPIO_ACTIVO FORMA_FARMACEUTICA  \
# 0                                          VALERIANA      SOLUCION ORAL
# 1                               EXTRACTO SECO DE AJO         NO REPORTA
# 2    MATERIAL HS TARAXACUM OFFICINALE DIENTE DE LEÓN             JARABE
# 3            MALVA MALVA SYLVESTRIS - HOJAS Y FLORES      SOLUCION ORAL
# 4  EXTRACTO SECO DE DIENTE DE LEON TARAXACUM OFFI...      SOLUCION ORAL
#
#   USOTERAPEUTICO INDICACIONES          CONDICION_VENTA     VIAUTIL  \
# 0      NO APLICA      SEDANTE  SIN FORMULA FACULTATIVA      2 AÑOS
# 1     NO REPORTA   NO REPORTA               NO REPORTA  NO REPORTA
# 2      NO APLICA    DIURÉTICO  SIN FORMULA FACULTATIVA      2 AÑOS
# 3   EXPECTORANTE   NO REPORTA  SIN FORMULA FACULTATIVA       1 AÑO
# 4      DIURETICO   NO REPORTA  SIN FORMULA FACULTATIVA       1 AÑO
#
#                                PRESENTACIONCOMERCIAL
# 0  CAJA POR UN FRASCO DE COLOR AMBAR TIPO II POR ...
# 1                             FRASCO POR 30 Y 120 ML
# 2  CAJA DE CARTON CON UN FRASCO DE VIDRIO TIPO II...
# 3  CAJA POR UN FRASCO DE VIDRIO TIPO II COLOR AMB...
# 4  CAJA CON UN FRASCO DE VIDRIO TIPO II COLOR AMB...

# %%
df.shape
# Out:
# (29467, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29467 entries, 0 to 29466
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   EXPEDIENTE                          29467 non-null  int64
#  1   REGISTRO_SANITARIO                  29467 non-null  object
#  2   FECHA_EXPEDICION                    22264 non-null  object
#  3   FECHA_VENCIMIENTO                   11516 non-null  object
#  4   PRODUCTO                            29467 non-null  object
#  5   TIPOPRODUCTO                        29467 non-null  object
#  6   TIPO_IDENTIFICACION_TITULAR         29467 non-null  object
#  7   IDENTIFICACION_TITULAR              29467 non-null  object
#  8   TITULAR                             29467 non-null  object
#  9   DIRECCIÓN_TITULAR                   29467 non-null  object
#  10  CIUDAD_TITULAR                      29467 non-null  object
#  11  ROL                                 29467 non-null  object
#  12  MODALIDAD                           29467 non-null  object
#  13  ESTADO_REGISTRO                     29467 non-null  object
#  14  MARCA                               29439 non-null  object
#  15  PRINCIPIO_ACTIVO                    29467 non-null  object
#  16  FORMA_FARMACEUTICA                  29467 non-null  object
#  17  USOTERAPEUTICO                      29467 non-null  object
#  18  INDICACIONES                        29467 non-null  object
#  19  CONTRA INDICACIONES Y ADVERTENCIAS  29445 non-null  object
#  20  CONDICION_VENTA                     29467 non-null  object
#  21  VIAUTIL                             29467 non-null  object
#  22  PRESENTACIONCOMERCIAL               29467 non-null  object
# dtypes: int64(1), object(22)
# memory usage: 5.2+ MB

# %%
# Se evidencia la presencia de valores nulos únicamente en algunas variables, principalmente asociadas a fechas.
df.isnull().sum()
# Out:
# EXPEDIENTE                                0
# REGISTRO_SANITARIO                        0
# FECHA_EXPEDICION                       7203
# FECHA_VENCIMIENTO                     17951
# PRODUCTO                                  0
# TIPOPRODUCTO                              0
# TIPO_IDENTIFICACION_TITULAR               0
# IDENTIFICACION_TITULAR                    0
# TITULAR                                   0
# DIRECCIÓN_TITULAR                         0
# CIUDAD_TITULAR                            0
# ROL                                       0
# MODALIDAD                                 0
# ESTADO_REGISTRO                           0
# MARCA                                    28
# PRINCIPIO_ACTIVO                          0
# FORMA_FARMACEUTICA                        0
# USOTERAPEUTICO                            0
# INDICACIONES                              0
# CONTRA INDICACIONES Y ADVERTENCIAS       22
# CONDICION_VENTA                           0
# VIAUTIL                                   0
# PRESENTACIONCOMERCIAL                     0
# dtype: int64

# %%
df = df.drop(columns=['FECHA_EXPEDICION', 'FECHA_VENCIMIENTO', "MARCA", "CONTRA INDICACIONES Y ADVERTENCIAS"])

#Se eliminan las valores nulos

# %%
df = df.dropna(axis=1, how='all')

# %%
df.isnull().sum()
# Out:
# EXPEDIENTE                     0
# REGISTRO_SANITARIO             0
# PRODUCTO                       0
# TIPOPRODUCTO                   0
# TIPO_IDENTIFICACION_TITULAR    0
# IDENTIFICACION_TITULAR         0
# TITULAR                        0
# DIRECCIÓN_TITULAR              0
# CIUDAD_TITULAR                 0
# ROL                            0
# MODALIDAD                      0
# ESTADO_REGISTRO                0
# PRINCIPIO_ACTIVO               0
# FORMA_FARMACEUTICA             0
# USOTERAPEUTICO                 0
# INDICACIONES                   0
# CONDICION_VENTA                0
# VIAUTIL                        0
# PRESENTACIONCOMERCIAL          0
# dtype: int64

# %%
df.duplicated().sum()

#Se eliminan registros duplicados
# Out:
# np.int64(143)

# %%
df = df.drop_duplicates()

# %%
columnas_texto = [
    'PRODUCTO', 'TIPOPRODUCTO', 'TITULAR',
    'CIUDAD_TITULAR', 'MODALIDAD', 'ESTADO_REGISTRO'
]

for col in columnas_texto:
    if col in df.columns:
        df[col] = (
            df[col]
            .astype(str)
            .str.strip()
            .str.upper()
        )

# %%
df.head()

#Se comprueba que la cantidad de datos este acorde con los requerimientos solicitados
# Out:
#    EXPEDIENTE    REGISTRO_SANITARIO  \
# 0      207398            NO REPORTA
# 1      207276            NO REPORTA
# 2      206425            NO REPORTA
# 3      204949  INVIMA 2001N-0000008
# 4      216969  INVIMA 2002N-0000105
#
#                                             PRODUCTO TIPOPRODUCTO  \
# 0                              EXTRACTO DE VALERIANA   NO REPORTA
# 1                                          ARLELLIUM   NO REPORTA
# 2                                             DIULED   NO REPORTA
# 3               BRONQUIOLIV MALVA SYLVESTRIS - MALVA   NO REPORTA
# 4  TARAXACUM OFFICINALIS DIENTE DE LEON SOLUCION ...   NO REPORTA
#
#   TIPO_IDENTIFICACION_TITULAR IDENTIFICACION_TITULAR  \
# 0                          NI          8.603.519.554
# 1                          NI          8.603.519.654
# 2                          NI          8.603.519.654
# 3                          NI          8.603.519.654
# 4                          NI          8.603.519.654
#
#                         TITULAR        DIRECCIÓN_TITULAR CIUDAD_TITULAR  \
# 0  LABORATORIOS PRONABELL S A S  CARRERA 12 NO 24 B - 45          FUNZA
# 1   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
# 2   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
# 3   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
# 4   LABORATORIOS PRONABELL LTDA     CARRERA 12 NO 24B 45          FUNZA
#
#           ROL          MODALIDAD ESTADO_REGISTRO  \
# 0  FABRICANTE  FABRICAR Y VENDER          NEGADO
# 1  FABRICANTE  FABRICAR Y VENDER          NEGADO
# 2  FABRICANTE  FABRICAR Y VENDER          NEGADO
# 3  FABRICANTE  FABRICAR Y VENDER         VENCIDO
# 4  FABRICANTE  FABRICAR Y VENDER         VENCIDO
#
#                                     PRINCIPIO_ACTIVO FORMA_FARMACEUTICA  \
# 0                                          VALERIANA      SOLUCION ORAL
# 1                               EXTRACTO SECO DE AJO         NO REPORTA
# 2    MATERIAL HS TARAXACUM OFFICINALE DIENTE DE LEÓN             JARABE
# 3            MALVA MALVA SYLVESTRIS - HOJAS Y FLORES      SOLUCION ORAL
# 4  EXTRACTO SECO DE DIENTE DE LEON TARAXACUM OFFI...      SOLUCION ORAL
#
#   USOTERAPEUTICO INDICACIONES          CONDICION_VENTA     VIAUTIL  \
# 0      NO APLICA      SEDANTE  SIN FORMULA FACULTATIVA      2 AÑOS
# 1     NO REPORTA   NO REPORTA               NO REPORTA  NO REPORTA
# 2      NO APLICA    DIURÉTICO  SIN FORMULA FACULTATIVA      2 AÑOS
# 3   EXPECTORANTE   NO REPORTA  SIN FORMULA FACULTATIVA       1 AÑO
# 4      DIURETICO   NO REPORTA  SIN FORMULA FACULTATIVA       1 AÑO
#
#                                PRESENTACIONCOMERCIAL
# 0  CAJA POR UN FRASCO DE COLOR AMBAR TIPO II POR ...
# 1                             FRASCO POR 30 Y 120 ML
# 2  CAJA DE CARTON CON UN FRASCO DE VIDRIO TIPO II...
# 3  CAJA POR UN FRASCO DE VIDRIO TIPO II COLOR AMB...
# 4  CAJA CON UN FRASCO DE VIDRIO TIPO II COLOR AMB...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29324 entries, 0 to 29466
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   EXPEDIENTE                   29324 non-null  int64
#  1   REGISTRO_SANITARIO           29324 non-null  object
#  2   PRODUCTO                     29324 non-null  object
#  3   TIPOPRODUCTO                 29324 non-null  object
#  4   TIPO_IDENTIFICACION_TITULAR  29324 non-null  object
#  5   IDENTIFICACION_TITULAR       29324 non-null  object
#  6   TITULAR                      29324 non-null  object
#  7   DIRECCIÓN_TITULAR            29324 non-null  object
#  8   CIUDAD_TITULAR               29324 non-null  object
#  9   ROL                          29324 non-null  object
#  10  MODALIDAD                    29324 non-null  object
#  11  ESTADO_REGISTRO              29324 non-null  object
#  12  PRINCIPIO_ACTIVO             29324 non-null  object
#  13  FORMA_FARMACEUTICA           29324 non-null  object
#  14  USOTERAPEUTICO               29324 non-null  object
#  15  INDICACIONES                 29324 non-null  object
#  16  CONDICION_VENTA              29324 non-null  object
#  17  VIAUTIL                      29324 non-null  object
#  18  PRESENTACIONCOMERCIAL        29324 non-null  object
# dtypes: int64(1), object(18)
# memory usage: 4.5+ MB

# %% [markdown]
# Durante la etapa de limpieza de datos se realizó la verificación de valores nulos, la eliminación de columnas completamente vacías y la depuración de registros duplicados. Adicionalmente, se estandarizaron variables categóricas sin realizar, con el fin de preservar la información original del conjunto de datos.

# %%
df.to_csv('/content/REGISTROS_SANITARIOS_DE_MEDICAMENTOS_HOMEOPÁTICOS_20251219.csv', index=False)

# %%
df.to_csv(
    '/content/medicamentos_homeopaticos_limpio.csv',
    index=False,
    encoding='utf-8-sig'
)

# %%
from google.colab import files
nombre_archivo = '/content/medicamentos_homeopaticos_limpio.csv'
files.download(nombre_archivo)
